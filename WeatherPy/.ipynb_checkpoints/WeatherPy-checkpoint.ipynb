# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
import json
import requests
from api_keys import weather_api_key
from citipy import citipy
import numpy as np
from pprint import pprint
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Generate Cities List

# %%
# Generate random latitudes and longitudes
rand_lat = np.random.uniform(-90,90,2000)
rand_lng = np.random.uniform(-180,180,2000)

# Create coordinate dataframe
coord_df = pd.DataFrame({'Latitude':rand_lat, 'Longitude':rand_lng})
coord_df
# Out:
#        Latitude   Longitude
# 0     11.245124  -66.824179
# 1     24.855711  113.782959
# 2    -53.770344 -151.746288
# 3     10.296658  -40.450688
# 4     38.380708  -85.490211
# ...         ...         ...
# 1995 -44.354764  150.536688
# 1996 -87.390674 -173.284642
# 1997  68.430070    0.910070
# 1998 -82.559021 -101.115224
# 1999  50.644595  -83.400622
#
# [2000 rows x 2 columns]

# %%
# Empty lists for cities and countries
cities = []
countries = []

# Locate city and country for respective latitudes and longitudes
for i in range(0,len(coord_df['Latitude'])):
    city = citipy.nearest_city(coord_df['Latitude'][i], coord_df['Longitude'][i])
    cities.append(city.city_name)
    countries.append(city.country_code)

#Add to coordinates dataframe    
coord_df['City'] = cities
coord_df['Country'] = countries

# Remove duplicate cities
city_df = tude_df.drop_duplicates('City', keep='first')
city_df = city_df.reset_index()
city_df
len(city_df)
# Out:
# 747

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %%
max_temps = []
humidities = []
clouds = []
wind_speeds = []
dates = []

for i in range(0,len(city_df['City'])):
    response = requests.get(query_url + city_df['City'][i]).json()
    
    try: 

        max_temps.append(response['main']['temp_max'])
        humidities.append(response['main']['humidity'])
        clouds.append(response['clouds']['all'])
        wind_speeds.append(response['wind']['speed'])
        dates.append(response['dt'])
        print(f'Processing Record {i} | {city_df["City"][i]}')
        
    except KeyError:
        max_temps.append(np.nan)
        humidities.append(np.nan)
        clouds.append(np.nan)
        wind_speeds.append(np.nan)
        dates.append(np.nan)
        print(f"Skipping {city_df['City'][i]} could not be found")
        
print('-----------------------------')
print('Data Retrieval Complete      ')
print('-----------------------------')
# Out:
# Processing Record 0 | chemal
# Processing Record 1 | chokurdakh
# Processing Record 2 | porto novo
# Processing Record 3 | ushuaia
# Processing Record 4 | sheltozero
# Processing Record 5 | albany
# Processing Record 6 | hamilton
# grand river south east could not be found
# Processing Record 8 | perth
# Processing Record 9 | quthing
# karauzyak could not be found
# belushya guba could not be found
# Processing Record 12 | saint-philippe
# Processing Record 13 | rikitea
# Processing Record 14 | ahuimanu
# Processing Record 15 | new norfolk
# Processing Record 16 | bilma
# Processing Record 17 | san vicente
# Processing Record 18 | meulaboh
# Processing Record 19 | cabo san lucas
# Processing Record 20 | nikolskoye
# mukhanovo could not be found
# Processing Record 22 | saskylakh
# Processing Record 23 | yamada
# Processing Record 24 | fairfield
# Processing Record 25 | langholm
# Processing Record 26 | moerai
# Processing Record 27 | adrar
# Processing Record 28 | carnarvon
# Processing Record 29 | bluff
# Processing Record 30 | mataura
# Processing Record 31 | hualmay
# Processing Record 32 | ballina
# Processing Record 33 | lebu
# Processing Record 34 | souillac
# Processing Record 35 | thompson
# Processing Record 36 | ambulu
# Processing Record 37 | bambous virieux
# Processing Record 38 | manokwari
# Processing Record 39 | yeppoon
# Processing Record 40 | tasiilaq
# Processing Record 41 | kalmunai
# Processing Record 42 | port alfred
# Processing Record 43 | torbay
# Processing Record 44 | uaua
# Processing Record 45 | polis
# Processing Record 46 | san miguel
# Processing Record 47 | hami
# Processing Record 48 | piranshahr
# Processing Record 49 | busselton
# eldikan could not be found
# Processing Record 51 | bubaque
# Processing Record 52 | koungheul
# Processing Record 53 | kapaa
# Processing Record 54 | wadi musa
# Processing Record 55 | inuvik
# Processing Record 56 | harper
# cumaribo could not be found
# Processing Record 58 | tiksi
# amderma could not be found
# Processing Record 60 | yellowknife
# Processing Record 61 | la ronge
# Processing Record 62 | kirakira
# Processing Record 63 | norman wells
# Processing Record 64 | xianshuigu
# Processing Record 65 | esperance
# Processing Record 66 | cidreira
# Processing Record 67 | kuvandyk
# Processing Record 68 | novopokrovka
# Processing Record 69 | bajil
# Processing Record 70 | port elizabeth
# Processing Record 71 | ahipara
# cockburn harbour could not be found
# Processing Record 73 | atuona
# Processing Record 74 | puerto ayora
# Processing Record 75 | fortuna
# Processing Record 76 | mahebourg
# Processing Record 77 | qaqortoq
# Processing Record 78 | sola
# Processing Record 79 | barrow
# Processing Record 80 | great yarmouth
# Processing Record 81 | cape town
# Processing Record 82 | praia da vitoria
# Processing Record 83 | punta arenas
# Processing Record 84 | nola
# Processing Record 85 | dikson
# Processing Record 86 | shelabolikha
# Processing Record 87 | ponta do sol
# taolanaro could not be found
# Processing Record 89 | butaritari
# Processing Record 90 | samana
# Processing Record 91 | avarua
# Processing Record 92 | san ramon
# Processing Record 93 | teeli
# zachagansk could not be found
# Processing Record 95 | vila franca do campo
# Processing Record 96 | namibe
# Processing Record 97 | vanavara
# Processing Record 98 | kuytun
# Processing Record 99 | roebourne
# Processing Record 100 | half moon bay
# Processing Record 101 | cururupu
# Processing Record 102 | takoradi
# Processing Record 103 | vaini
# Processing Record 104 | hasaki
# Processing Record 105 | goderich
# Processing Record 106 | hilo
# Processing Record 107 | mantua
# Processing Record 108 | victoria
# Processing Record 109 | brandon
# Processing Record 110 | qiqihar
# Processing Record 111 | banswara
# krasnoyarsk-45 could not be found
# Processing Record 113 | mar del plata
# Processing Record 114 | hobart
# Processing Record 115 | talnakh
# Processing Record 116 | vieste
# bacuit could not be found
# vaitupu could not be found
# Processing Record 119 | santa cruz
# Processing Record 120 | orhei
# Processing Record 121 | haines junction
# Processing Record 122 | grand gaube
# Processing Record 123 | hermanus
# Processing Record 124 | jamestown
# Processing Record 125 | tyrma
# Processing Record 126 | qaanaaq
# Processing Record 127 | sucila
# Processing Record 128 | georgetown
# chagda could not be found
# Processing Record 130 | hithadhoo
# Processing Record 131 | eregli
# Processing Record 132 | te anau
# Processing Record 133 | solnechnyy
# Processing Record 134 | morgan city
# Processing Record 135 | uige
# Processing Record 136 | saint george
# Processing Record 137 | ratnagiri
# Processing Record 138 | fremont
# Processing Record 139 | bredasdorp
# Processing Record 140 | verkhoyansk
# Processing Record 141 | noumea
# Processing Record 142 | walvis bay
# Processing Record 143 | tuatapere
# Processing Record 144 | luderitz
# Processing Record 145 | moba
# Processing Record 146 | pevek
# Processing Record 147 | mozarlandia
# Processing Record 148 | kalavad
# Processing Record 149 | bandarbeyla
# Processing Record 150 | leningradskiy
# Processing Record 151 | vilyuysk
# Processing Record 152 | oranjestad
# Processing Record 153 | medianeira
# Processing Record 154 | cloquet
# Processing Record 155 | bahia blanca
# Processing Record 156 | bethel
# Processing Record 157 | tuktoyaktuk
# Processing Record 158 | pisco
# Processing Record 159 | upernavik
# Processing Record 160 | sakaraha
# Processing Record 161 | sitangkai
# Processing Record 162 | castro
# sentyabrskiy could not be found
# Processing Record 164 | geraldton
# Processing Record 165 | churuquita chiquita
# Processing Record 166 | longyearbyen
# Processing Record 167 | jalingo
# Processing Record 168 | amahai
# Processing Record 169 | san patricio
# Processing Record 170 | banda aceh
# Processing Record 171 | auki
# Processing Record 172 | monywa
# Processing Record 173 | tubmanburg
# Processing Record 174 | puerto madryn
# Processing Record 175 | aklavik
# Processing Record 176 | inirida
# Processing Record 177 | grindavik
# Processing Record 178 | fairbanks
# Processing Record 179 | bosaso
# Processing Record 180 | sisimiut
# Processing Record 181 | petropavlovsk-kamchatskiy
# Processing Record 182 | sri aman
# Processing Record 183 | eydhafushi
# Processing Record 184 | chipata
# Processing Record 185 | nipawin
# samusu could not be found
# Processing Record 187 | namatanai
# Processing Record 188 | turkistan
# Processing Record 189 | san jose
# kobojango could not be found
# Processing Record 191 | zhigalovo
# Processing Record 192 | igarka
# Processing Record 193 | husavik
# Processing Record 194 | college
# Processing Record 195 | manaure
# Processing Record 196 | airai
# Processing Record 197 | kemin
# Processing Record 198 | kushiro
# Processing Record 199 | wencheng
# saleaula could not be found
# Processing Record 201 | vao
# Processing Record 202 | icod de los vinos
# Processing Record 203 | moose factory
# Processing Record 204 | codrington
# mys shmidta could not be found
# Processing Record 206 | rio bueno
# Processing Record 207 | east london
# Processing Record 208 | khatanga
# afgoye could not be found
# Processing Record 210 | samoylovka
# sungai siput utara could not be found
# Processing Record 212 | sakaiminato
# palabuhanratu could not be found
# Processing Record 214 | bengkulu
# Processing Record 215 | karak
# Processing Record 216 | itarema
# Processing Record 217 | marawi
# Processing Record 218 | nemuro
# Processing Record 219 | russell
# Processing Record 220 | nuuk
# Processing Record 221 | nome
# Processing Record 222 | saldanha
# Processing Record 223 | katsuura
# Processing Record 224 | jagatsinghapur
# Processing Record 225 | korla
# Processing Record 226 | tura
# Processing Record 227 | camacha
# Processing Record 228 | lumberton
# tsihombe could not be found
# Processing Record 230 | sungaipenuh
# Processing Record 231 | kita
# Processing Record 232 | pochutla
# Processing Record 233 | pacific grove
# Processing Record 234 | ostersund
# Processing Record 235 | vila velha
# Processing Record 236 | iqaluit
# Processing Record 237 | bhor
# Processing Record 238 | makakilo city
# Processing Record 239 | severo-kurilsk
# Processing Record 240 | kilindoni
# Processing Record 241 | klaksvik
# Processing Record 242 | hakkari
# Processing Record 243 | ponta delgada
# ardistan could not be found
# Processing Record 245 | ankara
# Processing Record 246 | mount gambier
# Processing Record 247 | pangnirtung
# Processing Record 248 | shingu
# Processing Record 249 | waddan
# Processing Record 250 | vestmannaeyjar
# Processing Record 251 | waingapu
# Processing Record 252 | karaidel
# Processing Record 253 | laguna
# Processing Record 254 | bairiki
# Processing Record 255 | solwezi
# Processing Record 256 | muros
# Processing Record 257 | chuy
# Processing Record 258 | mookane
# Processing Record 259 | sao joao da barra
# nizhneyansk could not be found
# Processing Record 261 | ayr
# Processing Record 262 | naze
# Processing Record 263 | comodoro rivadavia
# Processing Record 264 | clyde river
# Processing Record 265 | astoria
# Processing Record 266 | zaysan
# Processing Record 267 | arraial do cabo
# paradwip could not be found
# Processing Record 269 | kruisfontein
# Processing Record 270 | poum
# barentsburg could not be found
# Processing Record 272 | choix
# Processing Record 273 | provideniya
# Processing Record 274 | acarau
# Processing Record 275 | moron
# Processing Record 276 | kavieng
# Processing Record 277 | yar-sale
# Processing Record 278 | kaitangata
# Processing Record 279 | novovelichkovskaya
# Processing Record 280 | petatlan
# Processing Record 281 | ribeira grande
# Processing Record 282 | bilibino
# Processing Record 283 | bijela
# Processing Record 284 | samarai
# Processing Record 285 | san rafael
# Processing Record 286 | faanui
# marcona could not be found
# Processing Record 288 | yulara
# Processing Record 289 | nantucket
# Processing Record 290 | alofi
# Processing Record 291 | necochea
# Processing Record 292 | lichuan
# Processing Record 293 | palmer
# Processing Record 294 | goundam
# Processing Record 295 | lompoc
# Processing Record 296 | miri
# Processing Record 297 | sept-iles
# Processing Record 298 | vila do maio
# Processing Record 299 | sioux lookout
# Processing Record 300 | ugoofaaru
# Processing Record 301 | mamlyutka
# Processing Record 302 | fort nelson
# Processing Record 303 | lavrentiya
# Processing Record 304 | tommot
# Processing Record 305 | kaka
# Processing Record 306 | vangaindrano
# Processing Record 307 | kibala
# Processing Record 308 | nikolayevsk-na-amure
# Processing Record 309 | huntersville
# Processing Record 310 | hofn
# Processing Record 311 | arlit
# Processing Record 312 | odda
# Processing Record 313 | alencon
# Processing Record 314 | saravan
# Processing Record 315 | floresta
# Processing Record 316 | maniitsoq
# Processing Record 317 | acapulco
# Processing Record 318 | lubango
# Processing Record 319 | borzya
# Processing Record 320 | sao miguel do araguaia
# sorvag could not be found
# Processing Record 322 | wajir
# Processing Record 323 | tabou
# Processing Record 324 | jardim
# Processing Record 325 | lorengau
# Processing Record 326 | omboue
# Processing Record 327 | biak
# Processing Record 328 | port lincoln
# Processing Record 329 | teahupoo
# Processing Record 330 | idaho falls
# Processing Record 331 | aleksandrov gay
# Processing Record 332 | rajgarh
# Processing Record 333 | southbridge
# Processing Record 334 | kodiak
# Processing Record 335 | nouadhibou
# illoqqortoormiut could not be found
# Processing Record 337 | nikita
# Processing Record 338 | sitka
# Processing Record 339 | yumen
# Processing Record 340 | tartagal
# Processing Record 341 | westport
# Processing Record 342 | shambu
# Processing Record 343 | gagino
# Processing Record 344 | tongling
# Processing Record 345 | kaminoyama
# Processing Record 346 | pavullo nel frignano
# Processing Record 347 | port moresby
# Processing Record 348 | tigil
# Processing Record 349 | biloela
# Processing Record 350 | broome
# Processing Record 351 | sol-iletsk
# Processing Record 352 | liwale
# Processing Record 353 | revelstoke
# Processing Record 354 | batagay-alyta
# Processing Record 355 | martinsville
# Processing Record 356 | kinshasa
# Processing Record 357 | pyaozerskiy
# Processing Record 358 | coahuayana
# Processing Record 359 | odesskoye
# Processing Record 360 | jawhar
# Processing Record 361 | antalaha
# Processing Record 362 | marystown
# Processing Record 363 | chone
# Processing Record 364 | ancud
# Processing Record 365 | praya
# Processing Record 366 | verkhnevilyuysk
# Processing Record 367 | nyurba
# Processing Record 368 | yuryev-polskiy
# Processing Record 369 | fonte boa
# Processing Record 370 | faya
# Processing Record 371 | mount isa
# Processing Record 372 | artyom
# Processing Record 373 | viedma
# tumannyy could not be found
# Processing Record 375 | bereda
# Processing Record 376 | safaga
# Processing Record 377 | cherskiy
# Processing Record 378 | salalah
# Processing Record 379 | piacabucu
# Processing Record 380 | saint augustine
# Processing Record 381 | puteyets
# Processing Record 382 | campo
# Processing Record 383 | bathsheba
# Processing Record 384 | nova russas
# Processing Record 385 | deputatskiy
# Processing Record 386 | teya
# Processing Record 387 | poso
# Processing Record 388 | thinadhoo
# Processing Record 389 | taketa
# rungata could not be found
# Processing Record 391 | tocopilla
# Processing Record 392 | zbarazh
# Processing Record 393 | suamico
# Processing Record 394 | padang
# Processing Record 395 | matay
# Processing Record 396 | limon
# Processing Record 397 | henties bay
# Processing Record 398 | touros
# Processing Record 399 | kassala
# Processing Record 400 | lahaina
# Processing Record 401 | dunedin
# Processing Record 402 | awjilah
# Processing Record 403 | brae
# Processing Record 404 | babu
# Processing Record 405 | ostrovnoy
# Processing Record 406 | qena
# longlac could not be found
# Processing Record 408 | salym
# Processing Record 409 | marsh harbour
# Processing Record 410 | assiniboia
# Processing Record 411 | paamiut
# Processing Record 412 | kargopol
# Processing Record 413 | maraa
# Processing Record 414 | marabba
# Processing Record 415 | batticaloa
# Processing Record 416 | atar
# Processing Record 417 | vrangel
# Processing Record 418 | havelock
# Processing Record 419 | visakhapatnam
# Processing Record 420 | tautira
# Processing Record 421 | saint-augustin
# Processing Record 422 | tual
# Processing Record 423 | teguldet
# Processing Record 424 | oistins
# Processing Record 425 | dombarovskiy
# Processing Record 426 | bima
# Processing Record 427 | taltal
# Processing Record 428 | olean
# Processing Record 429 | huilong
# malwan could not be found
# Processing Record 431 | nanortalik
# Processing Record 432 | kahului
# Processing Record 433 | weyburn
# Processing Record 434 | shimoda
# Processing Record 435 | sukumo
# Processing Record 436 | vanimo
# Processing Record 437 | santa maria
# bur gabo could not be found
# Processing Record 439 | pamantingan
# Processing Record 440 | silopi
# Processing Record 441 | kudahuvadhoo
# Processing Record 442 | hokitika
# Processing Record 443 | hof
# Processing Record 444 | nanga eboko
# Processing Record 445 | guebwiller
# Processing Record 446 | geilenkirchen
# attawapiskat could not be found
# Processing Record 448 | kimbe
# Processing Record 449 | lata
# Processing Record 450 | pak phanang
# Processing Record 451 | chardara
# Processing Record 452 | utrecht
# Processing Record 453 | enshi
# Processing Record 454 | kieta
# Processing Record 455 | puerto escondido
# Processing Record 456 | zonguldak
# Processing Record 457 | harlingen
# Processing Record 458 | sao filipe
# Processing Record 459 | vardo
# fort saint john could not be found
# Processing Record 461 | phenix city
# Processing Record 462 | emerald
# Processing Record 463 | monchegorsk
# Processing Record 464 | rundu
# Processing Record 465 | ekhabi
# Processing Record 466 | yakeshi
# Processing Record 467 | wewak
# Processing Record 468 | letpadan
# Processing Record 469 | hwange
# Processing Record 470 | dwarka
# Processing Record 471 | constitucion
# Processing Record 472 | kharp
# Processing Record 473 | sturgis
# Processing Record 474 | ibotirama
# Processing Record 475 | shuangcheng
# Processing Record 476 | nanakuli
# Processing Record 477 | rocha
# Processing Record 478 | qasigiannguit
# Processing Record 479 | lulea
# Processing Record 480 | marsa matruh
# Processing Record 481 | pampas
# Processing Record 482 | khandyga
# Processing Record 483 | ambilobe
# Processing Record 484 | osoyoos
# Processing Record 485 | las vegas
# meyungs could not be found
# Processing Record 487 | punto fijo
# Processing Record 488 | gizo
# Processing Record 489 | campechuela
# Processing Record 490 | cap malheureux
# Processing Record 491 | ulladulla
# Processing Record 492 | gerash
# Processing Record 493 | lagoa
# Processing Record 494 | bangolo
# Processing Record 495 | espanola
# Processing Record 496 | bolshaya sosnova
# Processing Record 497 | vero beach
# Processing Record 498 | benguela
# Processing Record 499 | awbari
# Processing Record 500 | nelson bay
# Processing Record 501 | baijiantan
# Processing Record 502 | ouadda
# Processing Record 503 | sungurlu
# Processing Record 504 | olafsvik
# umzimvubu could not be found
# Processing Record 506 | el reno
# Processing Record 507 | lakatoro
# Processing Record 508 | todos santos
# Processing Record 509 | nizwa
# Processing Record 510 | samdari
# Processing Record 511 | totma
# Processing Record 512 | canto do buriti
# Processing Record 513 | gander
# Processing Record 514 | rudbar
# Processing Record 515 | krasnyy chikoy
# Processing Record 516 | kijang
# Processing Record 517 | kindu
# Processing Record 518 | maragogi
# Processing Record 519 | ishigaki
# Processing Record 520 | indramayu
# Processing Record 521 | sobolevo
# Processing Record 522 | mayo
# Processing Record 523 | anshun
# galiwinku could not be found
# Processing Record 525 | ranong
# Processing Record 526 | baracoa
# Processing Record 527 | kubuta
# Processing Record 528 | solihull
# Processing Record 529 | sugar hill
# barawe could not be found
# solovetskiy could not be found
# Processing Record 532 | coquimbo
# Processing Record 533 | port blair
# Processing Record 534 | scarborough
# Processing Record 535 | narasannapeta
# Processing Record 536 | matagami
# Processing Record 537 | vostok
# Processing Record 538 | jatai
# Processing Record 539 | richards bay
# crab hill could not be found
# Processing Record 541 | san mateo ixtatan
# Processing Record 542 | surany
# Processing Record 543 | mormugao
# Processing Record 544 | anderson
# Processing Record 545 | alta floresta
# Processing Record 546 | koindu
# Processing Record 547 | ambon
# Processing Record 548 | ankang
# Processing Record 549 | beringovskiy
# Processing Record 550 | calabozo
# Processing Record 551 | sibu
# Processing Record 552 | merrill
# Processing Record 553 | chalons-en-champagne
# Processing Record 554 | kuah
# Processing Record 555 | albania
# Processing Record 556 | kharhial
# Processing Record 557 | igrim
# Processing Record 558 | alappuzha
# Processing Record 559 | ardakan
# Processing Record 560 | motygino
# Processing Record 561 | leticia
# Processing Record 562 | grand forks
# Processing Record 563 | indiaroba
# Processing Record 564 | shatalovo
# Processing Record 565 | angleton
# Processing Record 566 | flinders
# Processing Record 567 | portland
# Processing Record 568 | kargasok
# Processing Record 569 | maningrida
# Processing Record 570 | cockburn town
# Processing Record 571 | prince rupert
# Processing Record 572 | la tuque
# Processing Record 573 | anloga
# balimo could not be found
# tarudant could not be found
# Processing Record 576 | lakes entrance
# Processing Record 577 | korem
# Processing Record 578 | hanyang
# Processing Record 579 | lufilufi
# Processing Record 580 | galle
# Processing Record 581 | gandhidham
# Processing Record 582 | zhigansk
# Processing Record 583 | ilulissat
# Processing Record 584 | tombouctou
# Processing Record 585 | zhanaozen
# Processing Record 586 | manono
# Processing Record 587 | amapa
# Processing Record 588 | jhalida
# Processing Record 589 | asau
# Processing Record 590 | energetik
# Processing Record 591 | beira
# Processing Record 592 | vigrestad
# Processing Record 593 | tungor
# Processing Record 594 | orlik
# Processing Record 595 | san pedro
# Processing Record 596 | padilla
# Processing Record 597 | mahenge
# Processing Record 598 | sao jose da coroa grande
# Processing Record 599 | roma
# Processing Record 600 | karratha
# Processing Record 601 | shu
# Processing Record 602 | kharan
# Processing Record 603 | benjamin aceval
# Processing Record 604 | dano
# Processing Record 605 | narsaq
# Processing Record 606 | livramento
# Processing Record 607 | koslan
# jujuy could not be found
# ust-kamchatsk could not be found
# felidhoo could not be found
# Processing Record 611 | hays
# Processing Record 612 | yarmouth
# Processing Record 613 | iquitos
# Processing Record 614 | lewistown
# Processing Record 615 | tacuarembo
# Processing Record 616 | batagay
# Processing Record 617 | siyabuswa
# Processing Record 618 | dingle
# Processing Record 619 | tahoua
# Processing Record 620 | sesheke
# Processing Record 621 | lesnoye
# Processing Record 622 | isangel
# nim ka thana could not be found
# taburi could not be found
# artyk could not be found
# Processing Record 626 | itoman
# Processing Record 627 | sishui
# Processing Record 628 | zeya
# Processing Record 629 | la libertad
# Processing Record 630 | seoul
# Processing Record 631 | aswan
# Processing Record 632 | lasa
# Processing Record 633 | ust-omchug
# Processing Record 634 | egvekinot
# Processing Record 635 | selikhino
# Processing Record 636 | calama
# Processing Record 637 | tan an
# mankovo-kalitvenskoye could not be found
# Processing Record 639 | valparaiso
# Processing Record 640 | cayenne
# Processing Record 641 | baoqing
# Processing Record 642 | orzhytsya
# Processing Record 643 | mundi
# Processing Record 644 | charleston
# Processing Record 645 | bonthe
# Processing Record 646 | asilah
# Processing Record 647 | morondava
# ondorhaan could not be found
# Processing Record 649 | zyryanka
# Processing Record 650 | port keats
# Processing Record 651 | avera
# Processing Record 652 | kokoda
# Processing Record 653 | port hedland
# Processing Record 654 | quatre cocos
# Processing Record 655 | ust-nera
# Processing Record 656 | pampierstad
# dzhusaly could not be found
# Processing Record 658 | newburn
# Processing Record 659 | velagici
# Processing Record 660 | ukiah
# Processing Record 661 | dentsville
# temaraia could not be found
# Processing Record 663 | matara
# Processing Record 664 | sao gabriel da cachoeira
# Processing Record 665 | krasnovishersk
# Processing Record 666 | ouesso
# Processing Record 667 | port augusta
# Processing Record 668 | bukene
# Processing Record 669 | connersville
# Processing Record 670 | waitati
# Processing Record 671 | broken hill
# Processing Record 672 | udachnyy
# Processing Record 673 | sibolga
# Processing Record 674 | leninskoye
# Processing Record 675 | gamba
# Processing Record 676 | valley city
# Processing Record 677 | almeria
# Processing Record 678 | alice springs
# Processing Record 679 | moindou
# Processing Record 680 | beyneu
# Processing Record 681 | tanout
# Processing Record 682 | gonzalez
# Processing Record 683 | kismayo
# Processing Record 684 | hambantota
# Processing Record 685 | the pas
# Processing Record 686 | maceio
# Processing Record 687 | la esperanza
# Processing Record 688 | mahon
# Processing Record 689 | misrikh
# Processing Record 690 | general teran
# kazalinsk could not be found
# Processing Record 692 | uarini
# Processing Record 693 | montepuez
# Processing Record 694 | bratsk
# Processing Record 695 | qaracala
# Processing Record 696 | huanren
# Processing Record 697 | gladstone
# Processing Record 698 | chokwe
# Processing Record 699 | cobija
# Processing Record 700 | alpena
# Processing Record 701 | rorvik
# Processing Record 702 | mayumba
# Processing Record 703 | simiti
# Processing Record 704 | labuhan
# Processing Record 705 | shetpe
# Processing Record 706 | yenagoa
# Processing Record 707 | soyo
# Processing Record 708 | frontera
# mouzakion could not be found
# Processing Record 710 | sistranda
# Processing Record 711 | arroyo
# Processing Record 712 | askim
# Processing Record 713 | veraval
# buariki could not be found
# Processing Record 715 | khasan
# Processing Record 716 | houma
# Processing Record 717 | shahrud
# Processing Record 718 | siniscola
# Processing Record 719 | orikum
# Processing Record 720 | west plains
# Processing Record 721 | doha
# Processing Record 722 | mardin
# Processing Record 723 | talpa
# Processing Record 724 | antofagasta
# Processing Record 725 | jacareacanga
# Processing Record 726 | mutoko
# sinjah could not be found
# Processing Record 728 | dali
# Processing Record 729 | berlevag
# Processing Record 730 | opuwo
# Processing Record 731 | osijek
# Processing Record 732 | loiza
# Processing Record 733 | majene
# Processing Record 734 | aykhal
# Processing Record 735 | griffith
# Processing Record 736 | komsomolskiy
# Processing Record 737 | tabas
# Processing Record 738 | buala
# Processing Record 739 | kargalinskaya
# Processing Record 740 | cootamundra
# Processing Record 741 | hobyo
# Processing Record 742 | zhelyabovka
# Processing Record 743 | carutapera
# Processing Record 744 | kosh-agach
# Processing Record 745 | akot
# Processing Record 746 | guadalajara
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
