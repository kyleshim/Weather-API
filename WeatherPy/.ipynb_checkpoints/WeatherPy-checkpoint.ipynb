# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
import json
import requests
from api_keys import weather_api_key
from citipy import citipy
import numpy as np
from pprint import pprint
import pandas as pd
import matplotlib.pyplot as plt
from datetime import date
import scipy.stats as st
from scipy.stats import linregress

# %% [markdown]
# ## Generate Cities List

# %%
# Generate random latitudes and longitudes
rand_lat = np.random.uniform(-90,90,2000)
rand_lng = np.random.uniform(-180,180,2000)

# Create coordinate dataframe
coord_df = pd.DataFrame({'Latitude':rand_lat, 'Longitude':rand_lng})
coord_df
# Out:
#        Latitude   Longitude
# 0     60.772440  148.993470
# 1     78.819784  -18.663049
# 2     43.609733   73.263802
# 3     77.954771    6.496933
# 4    -16.163084  154.280064
# ...         ...         ...
# 1995 -39.011521   26.659458
# 1996 -41.164901    6.504381
# 1997 -74.261029   42.265160
# 1998  -9.876591  101.632894
# 1999  75.773096   -0.219185
#
# [2000 rows x 2 columns]

# %%
# Empty lists for cities and countries
cities = []
countries = []

# Locate city and country for respective latitudes and longitudes
for i in range(0,len(coord_df['Latitude'])):
    city = citipy.nearest_city(coord_df['Latitude'][i], coord_df['Longitude'][i])
    cities.append(city.city_name)
    countries.append(city.country_code)

#Add to coordinates dataframe    
coord_df['City'] = cities
coord_df['Country'] = countries

# Remove duplicate cities
city_df = coord_df.drop_duplicates('City', keep='first')
city_df = city_df.reset_index()
city_df
len(city_df)
# Out:
# 762

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %%
max_temps = []
humidities = []
clouds = []
wind_speeds = []
dates = []
new_lat = []
new_lng = []
new_cities = []
new_countries = []

for i in range(0,len(city_df['City'])):
    response = requests.get(query_url + city_df['City'][i]).json()
    
    try: 
        max_temps.append(response['main']['temp_max'])
        humidities.append(response['main']['humidity'])
        clouds.append(response['clouds']['all'])
        wind_speeds.append(response['wind']['speed'])
        dates.append(response['dt'])
        new_lat.append(response['coord']['lat'])
        new_lng.append(response['coord']['lon'])
        new_cities.append(response['name'])
        new_countries.append(response['sys']['country'])
        print(f'Processing Record {i} | {city_df["City"][i]}')
        
    except KeyError:
        max_temps.append(np.nan)
        humidities.append(np.nan)
        clouds.append(np.nan)
        wind_speeds.append(np.nan)
        dates.append(np.nan)
        new_lat.append(np.nan)
        new_lng.append(np.nan)
        new_cities.append(np.nan)
        new_countries.append(np.nan)
        print(f"Skipping {city_df['City'][i]} could not be found")
        
print('-----------------------------')
print('Data Retrieval Complete      ')
print('-----------------------------')
# Out:
# Processing Record 0 | ust-omchug
# Skipping illoqqortoormiut could not be found
# Processing Record 2 | shu
# Skipping barentsburg could not be found
# Processing Record 4 | samarai
# Processing Record 5 | vaini
# Processing Record 6 | bluff
# Processing Record 7 | punta arenas
# Processing Record 8 | naze
# Skipping taolanaro could not be found
# Processing Record 10 | paamiut
# Processing Record 11 | banda aceh
# Processing Record 12 | thompson
# Processing Record 13 | new norfolk
# Processing Record 14 | albany
# Processing Record 15 | ulaanbaatar
# Processing Record 16 | saiha
# Processing Record 17 | ribeira grande
# Processing Record 18 | cangucu
# Processing Record 19 | cabadiangan
# Processing Record 20 | rocha
# Processing Record 21 | lincoln
# Processing Record 22 | chunoyar
# Processing Record 23 | coruripe
# Processing Record 24 | hermanus
# Processing Record 25 | port lincoln
# Processing Record 26 | bilibino
# Skipping grand centre could not be found
# Processing Record 28 | kapaa
# Processing Record 29 | busselton
# Skipping attawapiskat could not be found
# Processing Record 31 | puerto ayora
# Processing Record 32 | dicabisagan
# Processing Record 33 | coihaique
# Processing Record 34 | pilar
# Processing Record 35 | celestun
# Processing Record 36 | adelaide
# Processing Record 37 | havoysund
# Processing Record 38 | mataura
# Processing Record 39 | chokurdakh
# Processing Record 40 | kruisfontein
# Processing Record 41 | ushuaia
# Processing Record 42 | port hardy
# Processing Record 43 | leningradskiy
# Processing Record 44 | nivala
# Processing Record 45 | qaanaaq
# Processing Record 46 | kavieng
# Processing Record 47 | barrow
# Processing Record 48 | chuy
# Processing Record 49 | tuktoyaktuk
# Skipping bolungarvik could not be found
# Processing Record 51 | rikitea
# Processing Record 52 | cockburn town
# Processing Record 53 | henties bay
# Processing Record 54 | banyo
# Processing Record 55 | itacoatiara
# Processing Record 56 | petatlan
# Processing Record 57 | lasa
# Processing Record 58 | atuona
# Skipping mys shmidta could not be found
# Processing Record 60 | mildura
# Processing Record 61 | shirokiy
# Processing Record 62 | basar
# Processing Record 63 | talnakh
# Processing Record 64 | hobart
# Skipping sentyabrskiy could not be found
# Processing Record 66 | khandyga
# Processing Record 67 | bredasdorp
# Skipping bababe could not be found
# Skipping amderma could not be found
# Processing Record 70 | cidreira
# Processing Record 71 | okakarara
# Processing Record 72 | provideniya
# Processing Record 73 | wukari
# Processing Record 74 | luanda
# Processing Record 75 | krasnorechenskiy
# Processing Record 76 | tanout
# Processing Record 77 | debica
# Skipping buqayq could not be found
# Processing Record 79 | mayo
# Processing Record 80 | ostrovnoy
# Processing Record 81 | jamestown
# Skipping vaitupu could not be found
# Processing Record 83 | el retorno
# Processing Record 84 | marawi
# Skipping belushya guba could not be found
# Processing Record 86 | gamba
# Processing Record 87 | torbay
# Processing Record 88 | hamilton
# Processing Record 89 | nome
# Processing Record 90 | kabanjahe
# Processing Record 91 | sitka
# Processing Record 92 | port alfred
# Processing Record 93 | mareeba
# Processing Record 94 | atambua
# Processing Record 95 | shache
# Processing Record 96 | champerico
# Processing Record 97 | carnarvon
# Skipping rungata could not be found
# Processing Record 99 | camana
# Processing Record 100 | ancud
# Processing Record 101 | port elizabeth
# Processing Record 102 | mount gambier
# Processing Record 103 | bay roberts
# Processing Record 104 | hualmay
# Processing Record 105 | longyearbyen
# Processing Record 106 | raudeberg
# Processing Record 107 | ust-maya
# Processing Record 108 | duku
# Processing Record 109 | marsaxlokk
# Processing Record 110 | vestmannaeyjar
# Processing Record 111 | saint-philippe
# Processing Record 112 | mushie
# Processing Record 113 | mahebourg
# Skipping blonduos could not be found
# Processing Record 115 | simao
# Processing Record 116 | georgetown
# Processing Record 117 | klaksvik
# Processing Record 118 | kaeo
# Processing Record 119 | makakilo city
# Processing Record 120 | buri
# Processing Record 121 | lavrentiya
# Processing Record 122 | sao joao da barra
# Skipping palabuhanratu could not be found
# Processing Record 124 | kazerun
# Processing Record 125 | cayenne
# Processing Record 126 | victoria
# Processing Record 127 | sulangan
# Processing Record 128 | upernavik
# Processing Record 129 | cape town
# Processing Record 130 | fougamou
# Processing Record 131 | chapais
# Processing Record 132 | hilo
# Processing Record 133 | sobolevo
# Processing Record 134 | yerbogachen
# Processing Record 135 | padang
# Processing Record 136 | hoquiam
# Skipping nizhneyansk could not be found
# Processing Record 138 | laguna
# Skipping jaramana could not be found
# Processing Record 140 | cerritos
# Processing Record 141 | hami
# Processing Record 142 | ekhabi
# Processing Record 143 | lufilufi
# Processing Record 144 | midland
# Processing Record 145 | rampur
# Processing Record 146 | solvychegodsk
# Processing Record 147 | shelburne
# Processing Record 148 | clausthal-zellerfeld
# Processing Record 149 | liverpool
# Processing Record 150 | yumen
# Processing Record 151 | rio verde de mato grosso
# Processing Record 152 | marand
# Processing Record 153 | ilulissat
# Processing Record 154 | cabo san lucas
# Processing Record 155 | solnechnyy
# Processing Record 156 | vila velha
# Processing Record 157 | okhotsk
# Processing Record 158 | airai
# Processing Record 159 | tasiilaq
# Processing Record 160 | bethel
# Processing Record 161 | alugan
# Processing Record 162 | chumikan
# Processing Record 163 | souillac
# Processing Record 164 | magadan
# Processing Record 165 | iqaluit
# Processing Record 166 | saint george
# Processing Record 167 | saurimo
# Processing Record 168 | khatanga
# Processing Record 169 | kamenka
# Processing Record 170 | dikson
# Processing Record 171 | otta
# Processing Record 172 | nyurba
# Processing Record 173 | omboue
# Processing Record 174 | arraial do cabo
# Processing Record 175 | fairbanks
# Skipping umzimvubu could not be found
# Processing Record 177 | la palma
# Processing Record 178 | baykit
# Processing Record 179 | los llanos de aridane
# Processing Record 180 | dunedin
# Processing Record 181 | vera cruz
# Processing Record 182 | chitungwiza
# Processing Record 183 | butaritari
# Processing Record 184 | muroto
# Processing Record 185 | hithadhoo
# Processing Record 186 | goundam
# Processing Record 187 | vardo
# Processing Record 188 | east london
# Processing Record 189 | te anau
# Processing Record 190 | barcelos
# Processing Record 191 | vila
# Processing Record 192 | pacific grove
# Processing Record 193 | gorontalo
# Processing Record 194 | castro
# Processing Record 195 | hailey
# Processing Record 196 | poum
# Processing Record 197 | mar del plata
# Processing Record 198 | vao
# Processing Record 199 | pevek
# Processing Record 200 | oistins
# Processing Record 201 | hambantota
# Processing Record 202 | russkaya polyana
# Processing Record 203 | batticaloa
# Processing Record 204 | bundaberg
# Processing Record 205 | komsomolskiy
# Processing Record 206 | marsh harbour
# Processing Record 207 | geraldton
# Processing Record 208 | dingle
# Processing Record 209 | ponta do sol
# Processing Record 210 | ornskoldsvik
# Skipping tsihombe could not be found
# Processing Record 212 | octeville
# Processing Record 213 | tuatapere
# Processing Record 214 | urla
# Processing Record 215 | praia da vitoria
# Processing Record 216 | ushtobe
# Processing Record 217 | severo-kurilsk
# Processing Record 218 | mehkar
# Processing Record 219 | luau
# Processing Record 220 | saint-pierre
# Processing Record 221 | saldanha
# Processing Record 222 | along
# Processing Record 223 | moshupa
# Processing Record 224 | saskylakh
# Processing Record 225 | lebu
# Processing Record 226 | yar-sale
# Processing Record 227 | shubarshi
# Processing Record 228 | bengkulu
# Processing Record 229 | sao luis de montes belos
# Processing Record 230 | paramonga
# Processing Record 231 | beloha
# Processing Record 232 | angoram
# Processing Record 233 | sola
# Processing Record 234 | rudnya
# Processing Record 235 | litovko
# Processing Record 236 | guerrero negro
# Skipping sataua could not be found
# Processing Record 238 | wahiawa
# Processing Record 239 | nikolskoye
# Processing Record 240 | egvekinot
# Processing Record 241 | llanes
# Processing Record 242 | karratha
# Processing Record 243 | siyabuswa
# Processing Record 244 | trairi
# Processing Record 245 | russkiy kameshkir
# Processing Record 246 | tezu
# Skipping saleaula could not be found
# Processing Record 248 | petropavlovsk-kamchatskiy
# Processing Record 249 | mkushi
# Processing Record 250 | fort nelson
# Processing Record 251 | belaya gora
# Processing Record 252 | licata
# Processing Record 253 | west bay
# Processing Record 254 | meulaboh
# Processing Record 255 | carutapera
# Processing Record 256 | weihai
# Processing Record 257 | vostok
# Processing Record 258 | ibra
# Processing Record 259 | rosa zarate
# Processing Record 260 | labrea
# Processing Record 261 | fez
# Processing Record 262 | shenjiamen
# Skipping samusu could not be found
# Processing Record 264 | manacapuru
# Processing Record 265 | dandong
# Processing Record 266 | tiksi
# Processing Record 267 | ewa beach
# Skipping barawe could not be found
# Processing Record 269 | honiara
# Processing Record 270 | omsukchan
# Processing Record 271 | constitucion
# Processing Record 272 | beyneu
# Processing Record 273 | gondar
# Processing Record 274 | nipawin
# Processing Record 275 | mega
# Processing Record 276 | fukagawa
# Processing Record 277 | lazaro cardenas
# Processing Record 278 | tilichiki
# Processing Record 279 | wajid
# Processing Record 280 | ipilan
# Processing Record 281 | tual
# Processing Record 282 | tabuk
# Processing Record 283 | troitskoye
# Processing Record 284 | high prairie
# Processing Record 285 | pahrump
# Processing Record 286 | berlevag
# Processing Record 287 | zhigansk
# Processing Record 288 | aklavik
# Processing Record 289 | pemangkat
# Processing Record 290 | kahului
# Processing Record 291 | drayton valley
# Processing Record 292 | taksimo
# Processing Record 293 | cherskiy
# Processing Record 294 | grindavik
# Processing Record 295 | tandur
# Processing Record 296 | filingue
# Processing Record 297 | umm kaddadah
# Processing Record 298 | victor harbor
# Processing Record 299 | kaitangata
# Processing Record 300 | mahajanga
# Processing Record 301 | alice town
# Processing Record 302 | roald
# Skipping addi ugri could not be found
# Processing Record 304 | nizhnevartovsk
# Processing Record 305 | korla
# Processing Record 306 | luwuk
# Processing Record 307 | bubaque
# Processing Record 308 | sawakin
# Processing Record 309 | oranjemund
# Processing Record 310 | bathsheba
# Processing Record 311 | camacha
# Processing Record 312 | podgorica
# Processing Record 313 | alyangula
# Processing Record 314 | raglan
# Processing Record 315 | auch
# Processing Record 316 | havre-saint-pierre
# Processing Record 317 | kirakira
# Processing Record 318 | norman wells
# Processing Record 319 | ocampo
# Processing Record 320 | carauari
# Processing Record 321 | ottawa
# Processing Record 322 | kushiro
# Processing Record 323 | fortuna
# Skipping doctor pedro p. pena could not be found
# Processing Record 325 | san jose
# Processing Record 326 | roding
# Processing Record 327 | katsuura
# Processing Record 328 | progreso
# Processing Record 329 | svetlogorsk
# Processing Record 330 | faanui
# Processing Record 331 | alofi
# Processing Record 332 | ampanihy
# Processing Record 333 | kodiak
# Processing Record 334 | deputatskiy
# Processing Record 335 | san cristobal
# Processing Record 336 | sinnamary
# Processing Record 337 | tura
# Processing Record 338 | novoagansk
# Processing Record 339 | nouadhibou
# Processing Record 340 | beringovskiy
# Skipping louisbourg could not be found
# Processing Record 342 | santa cruz de tenerife
# Processing Record 343 | naantali
# Processing Record 344 | abu dhabi
# Processing Record 345 | sao filipe
# Processing Record 346 | kapit
# Processing Record 347 | cuencame
# Processing Record 348 | mersing
# Processing Record 349 | batagay-alyta
# Processing Record 350 | ganganagar
# Processing Record 351 | avarua
# Processing Record 352 | itaborai
# Processing Record 353 | san ramon
# Processing Record 354 | clyde river
# Skipping ozgon could not be found
# Skipping tumannyy could not be found
# Processing Record 357 | sechura
# Processing Record 358 | tupelo
# Processing Record 359 | naron
# Processing Record 360 | siderno
# Processing Record 361 | mangrol
# Skipping lolua could not be found
# Processing Record 363 | san patricio
# Processing Record 364 | kattivakkam
# Processing Record 365 | pringsewu
# Processing Record 366 | tutoia
# Processing Record 367 | boueni
# Processing Record 368 | lagoa
# Processing Record 369 | pampa
# Processing Record 370 | tomatlan
# Processing Record 371 | wakkanai
# Processing Record 372 | shingu
# Processing Record 373 | narsaq
# Processing Record 374 | kidal
# Processing Record 375 | locri
# Processing Record 376 | kindu
# Processing Record 377 | frohnleiten
# Skipping koboldo could not be found
# Skipping gulshat could not be found
# Skipping ruatoria could not be found
# Processing Record 381 | cap malheureux
# Processing Record 382 | benicarlo
# Processing Record 383 | canto do buriti
# Processing Record 384 | kiunga
# Processing Record 385 | carballo
# Processing Record 386 | umm lajj
# Processing Record 387 | riverton
# Processing Record 388 | sokoni
# Processing Record 389 | kurilsk
# Processing Record 390 | nizhniy tsasuchey
# Processing Record 391 | gaya
# Processing Record 392 | bambous virieux
# Processing Record 393 | westport
# Processing Record 394 | kourou
# Processing Record 395 | yuancheng
# Processing Record 396 | keene
# Processing Record 397 | shitanjing
# Processing Record 398 | touros
# Processing Record 399 | adiake
# Processing Record 400 | pag
# Processing Record 401 | isangel
# Processing Record 402 | krabi
# Processing Record 403 | balaguer
# Processing Record 404 | sterling
# Processing Record 405 | hennebont
# Processing Record 406 | menongue
# Processing Record 407 | magistralnyy
# Processing Record 408 | kita
# Processing Record 409 | fukue
# Processing Record 410 | payakumbuh
# Processing Record 411 | challapata
# Processing Record 412 | nantucket
# Processing Record 413 | basco
# Processing Record 414 | port hedland
# Processing Record 415 | barra do garcas
# Processing Record 416 | bhimunipatnam
# Processing Record 417 | vagur
# Processing Record 418 | puri
# Processing Record 419 | hasaki
# Processing Record 420 | inuvik
# Processing Record 421 | newbury
# Processing Record 422 | pedasi
# Processing Record 423 | general pico
# Processing Record 424 | edgewater
# Processing Record 425 | pervomayskoye
# Processing Record 426 | concordia sagittaria
# Processing Record 427 | jacareacanga
# Skipping marcona could not be found
# Processing Record 429 | kanniyakumari
# Processing Record 430 | jinxi
# Processing Record 431 | wajir
# Processing Record 432 | rosarito
# Processing Record 433 | nyrob
# Processing Record 434 | bogovarovo
# Processing Record 435 | shakawe
# Processing Record 436 | lakes entrance
# Processing Record 437 | haapiti
# Processing Record 438 | alta floresta
# Processing Record 439 | raga
# Processing Record 440 | grand gaube
# Processing Record 441 | muros
# Processing Record 442 | jasdan
# Processing Record 443 | valdivia
# Processing Record 444 | waipawa
# Processing Record 445 | broken hill
# Processing Record 446 | mehamn
# Processing Record 447 | warri
# Processing Record 448 | tautira
# Processing Record 449 | seymchan
# Processing Record 450 | lompoc
# Processing Record 451 | yellowknife
# Processing Record 452 | lamu
# Processing Record 453 | kyshtovka
# Processing Record 454 | inongo
# Processing Record 455 | calvinia
# Processing Record 456 | katobu
# Processing Record 457 | alizai
# Processing Record 458 | micheweni
# Skipping burica could not be found
# Processing Record 460 | napasar
# Processing Record 461 | college
# Skipping dera din panah could not be found
# Processing Record 463 | kasamwa
# Processing Record 464 | mansfield
# Processing Record 465 | taltal
# Processing Record 466 | chillicothe
# Processing Record 467 | salalah
# Processing Record 468 | arman
# Skipping chaa-khol could not be found
# Processing Record 470 | lorengau
# Processing Record 471 | rabo de peixe
# Processing Record 472 | tab
# Processing Record 473 | ciudad bolivar
# Processing Record 474 | fallon
# Processing Record 475 | kenmare
# Processing Record 476 | melfi
# Processing Record 477 | los palacios
# Processing Record 478 | najran
# Processing Record 479 | floro
# Processing Record 480 | huai yot
# Processing Record 481 | jalu
# Processing Record 482 | pierre
# Processing Record 483 | lethem
# Processing Record 484 | heyang
# Processing Record 485 | pangkalanbuun
# Processing Record 486 | haizhou
# Processing Record 487 | yulara
# Skipping acuna could not be found
# Processing Record 489 | galle
# Processing Record 490 | bowen
# Processing Record 491 | calahorra
# Skipping grand river south east could not be found
# Skipping turtkul could not be found
# Processing Record 494 | santa cruz
# Processing Record 495 | codrington
# Processing Record 496 | san carlos de bariloche
# Processing Record 497 | salmo
# Processing Record 498 | ust-koksa
# Skipping halalo could not be found
# Processing Record 500 | flinders
# Processing Record 501 | esperance
# Processing Record 502 | msanga
# Processing Record 503 | campeche
# Processing Record 504 | gondanglegi
# Processing Record 505 | kakonko
# Processing Record 506 | caravelas
# Processing Record 507 | vila franca do campo
# Processing Record 508 | dunhua
# Processing Record 509 | southbridge
# Processing Record 510 | olga
# Processing Record 511 | atar
# Processing Record 512 | majene
# Processing Record 513 | maues
# Processing Record 514 | vanimo
# Processing Record 515 | nelson bay
# Processing Record 516 | galveston
# Processing Record 517 | luwingu
# Processing Record 518 | gat
# Processing Record 519 | kathmandu
# Processing Record 520 | ulan-ude
# Processing Record 521 | pisco
# Processing Record 522 | harper
# Processing Record 523 | boyolangu
# Processing Record 524 | laohekou
# Processing Record 525 | channel-port aux basques
# Processing Record 526 | rawson
# Processing Record 527 | hede
# Processing Record 528 | maner
# Processing Record 529 | saint-augustin
# Processing Record 530 | aksarka
# Processing Record 531 | mercedes
# Processing Record 532 | reshetylivka
# Processing Record 533 | hadejia
# Processing Record 534 | kalashnikovo
# Processing Record 535 | susanville
# Processing Record 536 | gweta
# Processing Record 537 | cibinong
# Processing Record 538 | azanka
# Processing Record 539 | ahipara
# Processing Record 540 | libenge
# Skipping bur gabo could not be found
# Processing Record 542 | shiraoi
# Skipping zhanatas could not be found
# Processing Record 544 | nisko
# Processing Record 545 | vicuna
# Processing Record 546 | urdoma
# Processing Record 547 | mitu
# Processing Record 548 | valle hermoso
# Processing Record 549 | dayong
# Processing Record 550 | santiago de cao
# Processing Record 551 | vaasa
# Processing Record 552 | draguignan
# Processing Record 553 | tabou
# Processing Record 554 | auki
# Processing Record 555 | tsalka
# Processing Record 556 | coahuayana
# Processing Record 557 | bafoulabe
# Processing Record 558 | ossora
# Processing Record 559 | brae
# Processing Record 560 | laya
# Skipping ksenyevka could not be found
# Processing Record 562 | bridlington
# Processing Record 563 | olafsvik
# Processing Record 564 | sain alto
# Skipping bajo baudo could not be found
# Processing Record 566 | keti bandar
# Processing Record 567 | kumluca
# Processing Record 568 | sirjan
# Skipping tabiauea could not be found
# Processing Record 570 | sumter
# Processing Record 571 | santa maria
# Processing Record 572 | gladstone
# Processing Record 573 | quesnel
# Processing Record 574 | mount isa
# Processing Record 575 | kavaratti
# Processing Record 576 | pavlodar
# Processing Record 577 | prado
# Processing Record 578 | okha
# Processing Record 579 | garachine
# Processing Record 580 | conceicao do araguaia
# Processing Record 581 | necochea
# Processing Record 582 | maputo
# Processing Record 583 | acarau
# Processing Record 584 | hofn
# Processing Record 585 | kashi
# Processing Record 586 | smolensk
# Processing Record 587 | lodwar
# Processing Record 588 | hornepayne
# Processing Record 589 | bara
# Processing Record 590 | syracuse
# Processing Record 591 | puerto escondido
# Skipping crab hill could not be found
# Processing Record 593 | mana
# Processing Record 594 | gravdal
# Processing Record 595 | zaysan
# Processing Record 596 | riyadh
# Processing Record 597 | phangnga
# Processing Record 598 | grand forks
# Processing Record 599 | yeppoon
# Processing Record 600 | saint-georges
# Processing Record 601 | puerto penasco
# Processing Record 602 | zeya
# Processing Record 603 | cocobeach
# Processing Record 604 | waw
# Processing Record 605 | itarema
# Processing Record 606 | sorland
# Processing Record 607 | abasolo
# Processing Record 608 | semey
# Processing Record 609 | zhangye
# Processing Record 610 | buala
# Processing Record 611 | mouzouras
# Processing Record 612 | the valley
# Processing Record 613 | luderitz
# Processing Record 614 | strathmore
# Processing Record 615 | westlock
# Processing Record 616 | urumqi
# Skipping tapaua could not be found
# Processing Record 618 | ambulu
# Processing Record 619 | novyy urgal
# Processing Record 620 | macamic
# Processing Record 621 | point pleasant
# Processing Record 622 | rosario
# Skipping temaraia could not be found
# Processing Record 624 | denpasar
# Processing Record 625 | inhambane
# Processing Record 626 | liku
# Processing Record 627 | ambon
# Processing Record 628 | kelso
# Processing Record 629 | kholodnyy
# Processing Record 630 | igrim
# Processing Record 631 | ngunguru
# Processing Record 632 | urengoy
# Processing Record 633 | binzhou
# Skipping meyungs could not be found
# Processing Record 635 | xinxiang
# Processing Record 636 | nenjiang
# Processing Record 637 | vuktyl
# Processing Record 638 | sukhovolya
# Processing Record 639 | apatity
# Processing Record 640 | nijar
# Processing Record 641 | tucuman
# Processing Record 642 | ayan
# Processing Record 643 | la rioja
# Processing Record 644 | gazojak
# Skipping kadykchan could not be found
# Processing Record 646 | markova
# Processing Record 647 | huarmey
# Processing Record 648 | leninskoye
# Processing Record 649 | ust-kut
# Processing Record 650 | manga
# Processing Record 651 | moron
# Processing Record 652 | caraballeda
# Processing Record 653 | lashio
# Processing Record 654 | aktash
# Processing Record 655 | marathon
# Processing Record 656 | catole do rocha
# Processing Record 657 | lexington
# Processing Record 658 | qaqortoq
# Processing Record 659 | bom jesus da lapa
# Processing Record 660 | karangampel
# Processing Record 661 | kieta
# Processing Record 662 | maceio
# Processing Record 663 | barra patuca
# Processing Record 664 | yashkul
# Processing Record 665 | chkalovskoye
# Processing Record 666 | abomey
# Processing Record 667 | kostomuksha
# Processing Record 668 | ketchikan
# Processing Record 669 | elkton
# Processing Record 670 | menomonie
# Processing Record 671 | kumano
# Processing Record 672 | peniche
# Skipping aflu could not be found
# Skipping wonji could not be found
# Processing Record 675 | kununurra
# Processing Record 676 | aswan
# Skipping puerto cortes could not be found
# Processing Record 678 | port blair
# Processing Record 679 | whitehorse
# Processing Record 680 | isla mujeres
# Processing Record 681 | bandarbeyla
# Processing Record 682 | guthrie
# Skipping cockburn harbour could not be found
# Processing Record 684 | fort smith
# Processing Record 685 | nanakuli
# Skipping karkaralinsk could not be found
# Processing Record 687 | severo-yeniseyskiy
# Processing Record 688 | lakatoro
# Processing Record 689 | araouane
# Processing Record 690 | salinopolis
# Processing Record 691 | yinchuan
# Processing Record 692 | phan thiet
# Skipping kracheh could not be found
# Processing Record 694 | katherine
# Processing Record 695 | tullahoma
# Processing Record 696 | zamora
# Skipping utiroa could not be found
# Processing Record 698 | bathurst
# Processing Record 699 | batemans bay
# Processing Record 700 | iki-burul
# Processing Record 701 | saint-francois
# Processing Record 702 | sarh
# Processing Record 703 | half moon bay
# Skipping balimo could not be found
# Processing Record 705 | banjar
# Processing Record 706 | jinxiang
# Processing Record 707 | washington
# Processing Record 708 | wajima
# Processing Record 709 | chernyy yar
# Processing Record 710 | moindou
# Processing Record 711 | kloulklubed
# Processing Record 712 | zyryanka
# Processing Record 713 | krasnoselkup
# Processing Record 714 | glendive
# Processing Record 715 | namatanai
# Processing Record 716 | severomuysk
# Processing Record 717 | nemuro
# Processing Record 718 | ust-nera
# Processing Record 719 | alexandria
# Processing Record 720 | terme
# Processing Record 721 | wucheng
# Processing Record 722 | le gosier
# Skipping khonuu could not be found
# Processing Record 724 | salonta
# Processing Record 725 | maarianhamina
# Processing Record 726 | mynay
# Processing Record 727 | krivosheino
# Processing Record 728 | sukhumi
# Processing Record 729 | zanjan
# Processing Record 730 | ardakan
# Processing Record 731 | sabang
# Processing Record 732 | teguldet
# Skipping chagda could not be found
# Processing Record 734 | nioro
# Processing Record 735 | murgab
# Processing Record 736 | alekseyevsk
# Processing Record 737 | adilcevaz
# Processing Record 738 | hermosillo
# Processing Record 739 | santa lucia
# Processing Record 740 | leshan
# Processing Record 741 | sernur
# Processing Record 742 | aberdeen
# Processing Record 743 | finschhafen
# Processing Record 744 | ellisras
# Skipping nguiu could not be found
# Processing Record 746 | moussoro
# Processing Record 747 | grants pass
# Processing Record 748 | alghero
# Skipping deh rawud could not be found
# Processing Record 750 | encruzilhada do sul
# Processing Record 751 | nanortalik
# Skipping afgoye could not be found
# Processing Record 753 | nago
# Processing Record 754 | aksay
# Processing Record 755 | lata
# Processing Record 756 | puerto leguizamo
# Processing Record 757 | udaipur
# Processing Record 758 | mbandaka
# Processing Record 759 | kalmunai
# Processing Record 760 | soavinandriana
# Processing Record 761 | labuhan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %% [markdown]
# ## weather_df = pd.DataFrame({'City':new_cities, 'Lat':new_lat,
#                            'Lng':new_lng, 'Max Temp':max_temps,
#                            'Humidity':humidities, 'Cloudiness':clouds,
#                            'Wind Speed':wind_speeds, 'Country':new_countries,
#                            'Date':dates})
# clean_weather_df = weather_df.dropna()
# clean_weather_df

# %%
date = date.fromtimestamp(clean_weather_df['Date'].mean())
clean_weather_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  698.000000  698.000000  698.000000  698.000000  698.000000  698.000000
# mean    21.101776   22.253778   70.397235   70.712034   54.553009    7.678883
# std     32.081947   91.368430   14.016342   19.096039   40.198084    5.296861
# min    -54.800000 -179.166700   33.800000   10.000000    0.000000    0.000000
# 25%     -4.926300  -58.271350   61.320000   59.000000    9.000000    3.620000
# 50%     25.658350   24.849050   72.940000   74.000000   64.500000    6.420000
# 75%     47.416700  106.326200   81.357500   85.000000   98.000000   10.622500
# max     78.218600  179.316700   99.860000  100.000000  100.000000   27.540000
#
#                Date
# count  6.980000e+02
# mean   1.627437e+09
# std    9.085470e+01
# min    1.627437e+09
# 25%    1.627437e+09
# 50%    1.627437e+09
# 75%    1.627437e+09
# max    1.627438e+09

# %%
# Export file as a CSV, without the Pandas index, but with the header
clean_weather_df.to_csv("../output_data/city_data.csv", index=False, header=True)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
clean_weather_df[clean_weather_df.Humidity > 100]
# Out:
# Empty DataFrame
# Columns: [City, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed, Country, Date]
# Index: []

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %%
clean_city_data = clean_weather_df
clean_city_data
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Ust'-Omchug  61.1500  149.6333     49.55      69.0        98.0
# 2               Chu  43.5983   73.7614     78.93      26.0         0.0
# 4           Samarai -10.6167  150.6667     78.96      87.0        88.0
# 5             Vaini -21.2000 -175.2000     69.96      83.0        75.0
# 6             Bluff -46.6000  168.3333     52.81      70.0        33.0
# ..              ...      ...       ...       ...       ...         ...
# 757         Udaipur  24.5712   73.6918     76.10      92.0       100.0
# 758        Mbandaka   0.0487   18.2603     68.81      53.0        12.0
# 759        Kalmunai   7.4167   81.8167     82.81      67.0       100.0
# 760  Soavinandriana -19.1667   46.7333     41.38      86.0         0.0
# 761         Labuhan  -6.8844  112.2051     82.00      65.0         5.0
#
#      Wind Speed Country          Date
# 0          7.43      RU  1.627437e+09
# 2          8.50      KZ  1.627437e+09
# 4         15.73      PG  1.627437e+09
# 5          8.05      TO  1.627437e+09
# 6          9.26      NZ  1.627437e+09
# ..          ...     ...           ...
# 757       15.19      IN  1.627438e+09
# 758        1.81      CD  1.627438e+09
# 759        2.84      LK  1.627438e+09
# 760        5.75      MG  1.627438e+09
# 761        5.73      ID  1.627438e+09
#
# [698 rows x 9 columns]

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(clean_city_data['Lat'], clean_city_data['Max Temp'], marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
plt.title(f"City Latitude vs. Max Temperature ({date})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid()
plt.savefig("../output_data/lat_temp.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(clean_city_data['Lat'], clean_city_data['Humidity'], marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
plt.title(f"City Latitude vs. Humidity ({date})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()
plt.savefig("../output_data/lat_hum.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(clean_city_data['Lat'], clean_city_data['Cloudiness'], marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
plt.title(f"City Latitude vs. Cloudiness ({date})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()
plt.savefig("../output_data/lat_cloud.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(clean_city_data['Lat'], clean_city_data['Wind Speed'], marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
plt.title(f"City Latitude vs. Wind Speed ({date})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()
plt.savefig("../output_data/lat_wind.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = clean_city_data['Lat'][clean_city_data['Lat'] > 0]
y_values = clean_city_data['Max Temp'][clean_city_data['Lat'] > 0]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(20,45),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.savefig("../output_data/lat_temp_north.png")
print(f"The r-value is: {rvalue**2}")
plt.show()
# Out:
# The r-value is: 0.3953912045824654

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = clean_city_data['Lat'][clean_city_data['Lat'] < 0]
y_values = clean_city_data['Max Temp'][clean_city_data['Lat'] < 0]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-25,35),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.savefig("../output_data/lat_temp_south.png")
print(f"The r-value is: {rvalue**2}")
plt.show()
# Out:
# The r-value is: 0.5040207672107522

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = clean_city_data['Lat'][clean_city_data['Lat'] > 0]
y_values = clean_city_data['Humidity'][clean_city_data['Lat'] > 0]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,30),fontsize=10,color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.savefig("../output_data/lat_hum_north.png")
print(f"The r-value is: {rvalue**2}")
plt.show()
# Out:
# The r-value is: 0.0031710291923646656

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = clean_city_data['Lat'][clean_city_data['Lat'] < 0]
y_values = clean_city_data['Humidity'][clean_city_data['Lat'] < 0]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,18),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.savefig("../output_data/lat_hum_south.png")
print(f"The r-value is: {rvalue**2}")
plt.show()
# Out:
# The r-value is: 3.843543548553945e-05

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = clean_city_data['Lat'][clean_city_data['Lat'] > 0]
y_values = clean_city_data['Cloudiness'][clean_city_data['Lat'] > 0]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(7,50),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.savefig("../output_data/lat_cloud_north.png")
print(f"The r-value is: {rvalue**2}")
plt.show()
# Out:
# The r-value is: 0.0006446970495184682

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = clean_city_data['Lat'][clean_city_data['Lat'] < 0]
y_values = clean_city_data['Cloudiness'][clean_city_data['Lat'] < 0]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-45,35),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.savefig("../output_data/lat_cloud_south.png")
print(f"The r-value is: {rvalue**2}")
plt.show()
# Out:
# The r-value is: 0.0001701188704131071

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = clean_city_data['Lat'][clean_city_data['Lat'] > 0]
y_values = clean_city_data['Wind Speed'][clean_city_data['Lat'] > 0]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(25,25),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.savefig("../output_data/lat_wind_north.png")
print(f"The r-value is: {rvalue**2}")
plt.show()
# Out:
# The r-value is: 0.007015502166856609

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = clean_city_data['Lat'][clean_city_data['Lat'] < 0]
y_values = clean_city_data['Wind Speed'][clean_city_data['Lat'] < 0]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-30,20),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.savefig("../output_data/lat_wind_south.png")
print(f"The r-value is: {rvalue**2}")
plt.show()
# Out:
# The r-value is: 0.03729916273119603
